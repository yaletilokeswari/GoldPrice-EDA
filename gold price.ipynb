# %% [markdown]
# # Exploratory Data Analysis on Gold Price
# <img src = "https://i.postimg.cc/Kc01yZFW/Chat-GPT-Image-Aug-9-2025-05-47-32-PM.png" width = "600" height = "100"><br>
# # Data Overview
# *The dataset captures historical gold price movements over a specific time period, providing a detailed breakdown of price behavior across different      trading sessions. Each record represents a time window during which gold was traded, along with essential price and volume information.
# * Gold is a global commodity whose price reflects economic trends, currency fluctuations, and geopolitical events. By analyzing this dataset, we can:
# * Detect upward or downward trends in gold prices over time.
# * Measure market volatility using daily high–low ranges.
# * Explore the relationship between trading volume and price changes.
# * Build predictive models for future price movements.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
volume =['timeOpen','timeClose','timeHigh','timeLow','priceOpen','priceHigh','priceLow','priceClose','volume']

# %%
df["volume"].value_counts().plot(kind='pie',autopct='%1.2f%%',title="goldprices")
plt.show()

# %% [markdown]
# #### 1. Load & Clean Dataset

# %%
file_path = "Gold_price_2025 new.csv"  # Update path if needed
df = pd.read_csv(file_path)

# %% [markdown]
# ##### Convert price columns to float

# %%
for col in ['priceOpen', 'priceHigh', 'priceLow', 'priceClose']:
    df[col] = df[col].str.replace(',', '.').astype(float)

# %% [markdown]
# ##### Convert timestamps to datetime

# %%
df['timeOpen'] = pd.to_datetime(df['timeOpen'], unit='ms')
df['timeClose'] = pd.to_datetime(df['timeClose'], unit='ms')

# %% [markdown]
# ##### Sort by time

# %%
df = df.sort_values('timeOpen')

# %% [markdown]
# ### 2. Dataset Overview

# %%
print("Shape:", df.shape)
print("\nMissing Values:\n", df.isnull().sum())
print("\nDate Range:", df['timeOpen'].min(), "to", df['timeOpen'].max())
print("\nSummary Statistics:\n", df.describe())
# Out:
# Shape: (664, 9)
#
# Missing Values:
#  timeOpen      0
# timeClose     0
# timeHigh      0
# timeLow       0
# priceOpen     0
# priceHigh     0
# priceLow      0
# priceClose    0
# volume        0
# dtype: int64
#
# Date Range: 2023-09-28 11:20:00 to 2025-07-26 11:40:00
#
# Summary Statistics:
#                              timeOpen                      timeClose  \
# count                            664                            664
# mean   2024-08-27 09:15:05.421686784  2024-08-28 09:15:06.024096512
# min              2023-09-28 11:20:00            2023-09-29 12:20:00
# 25%              2024-03-14 06:25:00            2024-03-15 05:20:00
# 50%              2024-08-26 23:30:00            2024-08-28 00:30:00
# 75%              2025-02-09 17:35:00            2025-02-10 18:35:00
# max              2025-07-26 11:40:00            2025-07-27 12:40:00
# std                              NaN                            NaN
#
#            timeHigh       timeLow   priceOpen   priceHigh    priceLow  \
# count  6.640000e+02  6.640000e+02  664.000000  664.000000  664.000000
# mean   1.724798e+12  1.724791e+12    0.030136    0.033000    0.028467
# min    1.695980e+12  1.695940e+12    0.000000    0.000000    0.000000
# 25%    1.710428e+12  1.710465e+12    0.013408    0.013778    0.013130
# 50%    1.724755e+12  1.724790e+12    0.018745    0.018766    0.018522
# 75%    1.739205e+12  1.739182e+12    0.038994    0.042855    0.036854
# max    1.753590e+12  1.753530e+12    0.175756    0.192623    0.161438
# std    1.664104e+10  1.663530e+10    0.028876    0.033254    0.026054
#
#        priceClose
# count  664.000000
# mean     0.029981
# min      0.000000
# 25%      0.013386
# 50%      0.018707
# 75%      0.038672
# max      0.175739
# std      0.028652

# %% [markdown]
# ### 3. Price Trend Over Time

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['timeOpen'], df['priceClose'], color='gold')
plt.title("Gold Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Monthly average prices

# %%
df['Month'] = df['timeOpen'].dt.to_period('M')
monthly_avg = df.groupby('Month')['priceClose'].mean()

plt.figure(figsize=(10, 5))
monthly_avg.plot(kind='bar', color='goldenrod')
plt.title("Average Monthly Closing Price")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 4. Price Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['priceClose'], bins=30, kde=True, color='gold')
plt.title("Distribution of Closing Prices")
plt.xlabel("Price")
plt.show()

plt.figure(figsize=(6, 1))
sns.boxplot(data=df[['priceOpen', 'priceHigh', 'priceLow', 'priceClose']], palette="autumn")
plt.title("Price Columns Distribution")
plt.show()

# %% [markdown]
# ### 5. Relationships Between Prices

# %% [markdown]
# plt.figure(figsize=(6, 6))
# sns.scatterplot(x='priceOpen', y='priceClose', data=df, color='orange')
# plt.title("Opening Price vs Closing Price")
# plt.show()
#
# plt.figure(figsize=(6, 6))
# sns.scatterplot(x='priceHigh', y='priceLow', data=df, color='red')
# plt.title("High Price vs Low Price")
# plt.show()

# %% [markdown]
# ##### Daily price range

# %%
df['Daily Range'] = df['priceHigh'] - df['priceLow']
plt.figure(figsize=(10, 5))
plt.bar(df['timeOpen'], df['Daily Range'], color='peru')
plt.title("Daily Price Range Over Time")
plt.xlabel("Date")
plt.ylabel("Price Range")
plt.show()

# %% [markdown]
# ### 6. Outlier Detection

# %%
plt.figure(figsize=(6, 1))
sns.boxplot(y='priceClose', data=df, color='gold')
plt.title("Outlier Detection - Closing Price")
plt.show()

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Load Dataset

# %%
df = pd.read_csv("Gold_price_2025 new.csv")

# %% [markdown]
# ##### Data Cleaning

# %%
df['timeOpen'] = pd.to_datetime(df['timeOpen'])
df['timeClose'] = pd.to_datetime(df['timeClose'])
numeric_cols = ['priceOpen', 'priceHigh', 'priceLow', 'priceClose', 'volume']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# ##### Sort by Date

# %%
df.sort_values('timeOpen', inplace=True)

# %% [markdown]
# ##### Dataset Overview

# %%
print("Dataset Shape:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
print("\nSummary Statistics:\n", df.describe())
# Out:
# Dataset Shape: (664, 9)
#
# Data Types:
#  timeOpen      datetime64[ns]
# timeClose     datetime64[ns]
# timeHigh             float64
# timeLow              float64
# priceOpen            float64
# priceHigh            float64
# priceLow             float64
# priceClose           float64
# volume               float64
# dtype: object
#
# Missing Values:
#  timeOpen        0
# timeClose       0
# timeHigh        0
# timeLow         0
# priceOpen     660
# priceHigh     660
# priceLow      660
# priceClose    660
# volume        442
# dtype: int64
#
# Summary Statistics:
#                              timeOpen                      timeClose  \
# count                            664                            664
# mean   1970-01-01 00:28:44.750105421  1970-01-01 00:28:44.836506024
# min       1970-01-01 00:28:15.900000     1970-01-01 00:28:15.990000
# 25%       1970-01-01 00:28:30.397500     1970-01-01 00:28:30.480000
# 50%       1970-01-01 00:28:44.715000     1970-01-01 00:28:44.805000
# 75%       1970-01-01 00:28:59.122500     1970-01-01 00:28:59.212500
# max       1970-01-01 00:29:13.530000     1970-01-01 00:29:13.620000
# std                              NaN                            NaN
#
#            timeHigh       timeLow  priceOpen  priceHigh  priceLow  priceClose  \
# count  6.640000e+02  6.640000e+02        4.0        4.0       4.0         4.0
# mean   1.724798e+12  1.724791e+12        0.0        0.0       0.0         0.0
# min    1.695980e+12  1.695940e+12        0.0        0.0       0.0         0.0
# 25%    1.710428e+12  1.710465e+12        0.0        0.0       0.0         0.0
# 50%    1.724755e+12  1.724790e+12        0.0        0.0       0.0         0.0
# 75%    1.739205e+12  1.739182e+12        0.0        0.0       0.0         0.0
# max    1.753590e+12  1.753530e+12        0.0        0.0       0.0         0.0
# std    1.664104e+10  1.663530e+10        0.0        0.0       0.0         0.0
#
#              volume
# count    222.000000
# mean     114.364865
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max    19751.000000
# std     1376.902937

# %% [markdown]
# ##### Missing Values Heatmap

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ##### Closing Price Over Time

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['timeOpen'], df['priceClose'], color='gold')
plt.title("Gold Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Monthly Average Prices

# %%
df['Month'] = df['timeOpen'].dt.to_period('M')
monthly_avg = df.groupby('Month')['priceClose'].mean()
plt.figure(figsize=(10, 5))
monthly_avg.plot(kind='bar', color='orange')
plt.title("Monthly Average Closing Price")
plt.xlabel("Month")
plt.ylabel("Average Price (USD)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Price Distribution (Histogram + KDE)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['priceClose'], kde=True, color='gold', bins=30)
plt.title("Distribution of Closing Prices")
plt.xlabel("Closing Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### for Price Columns

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df[['priceOpen', 'priceHigh', 'priceLow', 'priceClose']])
plt.title("Price Distribution (Open, High, Low, Close)")
plt.show()

# %% [markdown]
# ##### Open vs Close

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='priceOpen', y='priceClose', data=df, color='darkorange')
plt.title("Open Price vs Close Price")
plt.xlabel("Open Price")
plt.ylabel("Close Price")
plt.show()

# %% [markdown]
# ##### High vs Low

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='priceHigh', y='priceLow', data=df, color='brown')
plt.title("High Price vs Low Price")
plt.xlabel("High Price")
plt.ylabel("Low Price")
plt.show()

# %% [markdown]
# ##### Daily Price Range

# %%
df['Daily Range'] = df['priceHigh'] - df['priceLow']
plt.figure(figsize=(10, 5))
plt.plot(df['timeOpen'], df['Daily Range'], color='red')
plt.title("Daily Price Range Over Time")
plt.xlabel("Date")
plt.ylabel("Price Range")
plt.show()

# %% [markdown]
# ##### Volume vs Daily Range

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='volume', y='Daily Range', data=df, color='purple')
plt.title("Volume vs Daily Price Range")
plt.xlabel("Trading Volume")
plt.ylabel("Daily Range")
plt.show()

# %% [markdown]
# ##### Outlier Detection

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['priceClose'], color='gold')
plt.title("Outliers in Closing Price")
plt.show()

# %% [markdown]
# ##### Correlation

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[numeric_cols + ['Daily Range']].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Project Summary – Gold Price Analysis

# %% [markdown]
# This project analyzes historical gold prices to identify trends, volatility patterns, and volume impacts on price movement. Using data cleaning, visualization, and correlation analysis, it uncovers how trading activity influences price fluctuations. Key findings reveal that high volume often aligns with sharp price changes, and closing prices offer clearer long-term trends. The insights can support future forecasting and investment decisions.

# %% [markdown]
# ### Future Work – Gold Price EDA Project

# %% [markdown]
# * Build predictive models (e.g., ARIMA, LSTM) to forecast future gold prices.
# * Incorporate external factors such as currency exchange rates, inflation, and global market indices.
# * Develop an interactive dashboard for real-time gold price monitoring.
# * Perform sentiment analysis using news headlines and social media to assess market influence.

# %% [markdown]
# ### References
# * Medium: https://medium.com/code-heroku/introduction-to-exploratory-data-analysis-eda-c0257f888676
# * Kaggle: https://www.kaggle.com/code/spscientist/a-simple-tutorial-on-exploratory-data-analysis
# * kaggle: https://www.kaggle.com/datasets/willianoliveiragibin/gold-price-2025
